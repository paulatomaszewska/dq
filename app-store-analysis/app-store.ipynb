# %% [markdown]
# ## App Store analysis
#
# The goal of this project is to analyze data to help our developers understand what type of apps are likely to attract more users.

# %% [markdown]
# First, I created a helper function to explore the data in an easy way.

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')  # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %% [markdown]
# In this cell I'm reading the datasets.

# %%
from csv import reader

apple_store_file_name = "AppleStore.csv"
google_play_store_file = "googleplaystore.csv"


def read_dataset_with(file_name):
    file = open(file_name)
    dataset = list(reader(file))

    return dataset


apple_store_dataset = read_dataset_with(apple_store_file_name)
google_store_dataset = read_dataset_with(google_play_store_file)

explore_data(apple_store_dataset, 0, 2, True)
explore_data(google_store_dataset, 0, 2, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# Number of rows: 7198
# Number of columns: 16
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# Number of rows: 10842
# Number of columns: 13

# %% [markdown]
# In this cell, I will be removing corrupt rows from each dataset. A corrupt row is a row that has a different number of columns than the header row.

# %%
def remove_corrupt_rows_from(raw_dataset):
    number_of_columns = len(raw_dataset[0])
    clean_dataset = [raw_dataset[0]]

    for row in raw_dataset[1:]:
        if len(row) == number_of_columns:
            clean_dataset.append(row)

    return clean_dataset


apple_store_dataset = remove_corrupt_rows_from(apple_store_dataset)
google_store_dataset = remove_corrupt_rows_from(google_store_dataset)

explore_data(apple_store_dataset, 0, 2, True)
explore_data(google_store_dataset, 0, 2, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# Number of rows: 7198
# Number of columns: 16
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %% [markdown]
# Next, I'm going to remove duplicated apps. I determine duplication as two apps having the same name. If it happens, I'll select the instance with the biggest number of ratings - because it suggests it's the newest piece of data about this app.

# %%
def remove_duplicated_apps_from(raw_dataset, name_column_index, rating_count_column_index):
    deduped_apps = {}
    header = raw_dataset[0]

    for app in raw_dataset[1:]:
        app_name = app[name_column_index]
        rating_count = app[rating_count_column_index]

        if app_name not in deduped_apps or rating_count > deduped_apps[app_name][rating_count_column_index]:
            deduped_apps[app_name] = app

    return [header] + list(deduped_apps.values())


apple_store_dataset = remove_duplicated_apps_from(apple_store_dataset, 1, 5)
google_store_dataset = remove_duplicated_apps_from(google_store_dataset, 0, 3)

explore_data(apple_store_dataset, 0, 2, True)
explore_data(google_store_dataset, 0, 2, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# Number of rows: 7196
# Number of columns: 16
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# Number of rows: 9660
# Number of columns: 13

# %% [markdown]
# The next step is to remove apps that are not English. It's not a smart language model - I'm just checking for the characters from the English aplhabet, punctuation and up to 3 other characters.

# %%
import re


def remove_non_english_apps(raw_dataset, name_column_index):
    english_apps = [raw_dataset[0]]


    for app in raw_dataset[1:]:
        app_name = app[name_column_index]

        non_ascii_pattern = re.compile(r'[^\x00-\x7F]')
        non_ascii_chars = non_ascii_pattern.findall(app_name)

        if len(non_ascii_chars) <= 3:
            english_apps.append(app)

    return english_apps


apple_store_dataset = remove_non_english_apps(apple_store_dataset, 1)
google_store_dataset = remove_non_english_apps(google_store_dataset, 0)

explore_data(apple_store_dataset, 0, 2, True)
explore_data(google_store_dataset, 0, 2, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# Number of rows: 6182
# Number of columns: 16
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# Number of rows: 9615
# Number of columns: 13

# %% [markdown]
# Since our interest is only in the free apps, I will remove the paid ones.

# %%
def remove_paid_apps(raw_dataset, price_column_index):
    free_apps = [raw_dataset[0]]

    for app in raw_dataset[1:]:
        try:
            price = float(app[price_column_index])
        except ValueError:
            price = float(app[price_column_index].replace("$", ""))

        if price == 0.0:
            free_apps.append(app)

    return free_apps

apple_store_dataset = remove_paid_apps(apple_store_dataset, 4)
google_store_dataset = remove_paid_apps(google_store_dataset, 7)

explore_data(apple_store_dataset, 0, 2, True)
explore_data(google_store_dataset, 0, 2, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# Number of rows: 3221
# Number of columns: 16
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# Number of rows: 8863
# Number of columns: 13

# %% [markdown]
# Now I want to display a frequency table that shows the share of each type of app genre within the remaining apps.

# %%
def create_percentage_frequency_table_for(raw_dataset, column_index):
    numerical_frequencies = {}
    percentage_frequencies = {}
    dataset = raw_dataset[1:]
    number_of_apps = len(dataset)

    for app in dataset:
        frequency_field = app[column_index]
        if frequency_field in numerical_frequencies:
            numerical_frequencies[frequency_field] += 1
        else:
            numerical_frequencies[frequency_field] = 1

    for frequency_field, frequency in numerical_frequencies.items():
        percentage_frequencies[frequency_field] = round(frequency / number_of_apps * 100, 2)


    return percentage_frequencies

apple_store_frequency_table = create_percentage_frequency_table_for(apple_store_dataset, 11)
google_store_category_frequency_table = create_percentage_frequency_table_for(google_store_dataset, 1)
google_store_genres_frequency_table = create_percentage_frequency_table_for(google_store_dataset, 9)

# %%
def display_table(table):
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %% [markdown]
# ### Apple store - prime_genre column

# %%
display_table(apple_store_frequency_table)
# Out:
# Games : 58.14
# Entertainment : 7.89
# Photo & Video : 4.97
# Education : 3.66
# Social Networking : 3.29
# Shopping : 2.61
# Utilities : 2.52
# Sports : 2.14
# Music : 2.05
# Health & Fitness : 2.02
# Productivity : 1.74
# Lifestyle : 1.58
# News : 1.34
# Travel : 1.24
# Finance : 1.12
# Weather : 0.87
# Food & Drink : 0.81
# Reference : 0.56
# Business : 0.53
# Book : 0.43
# Navigation : 0.19
# Medical : 0.19
# Catalogs : 0.12

# %% [markdown]
# **What is the most common genre? What is the next most common?**\
# The vast majority (58%) of the free, English apps are Games, the next category (8%) is Entertainment.
#
# **What is the general impression — are most of the apps designed for practical purposes (education, shopping, utilities, productivity, lifestyle) or more for entertainment (games, photo and video, social networking, sports, music)?**\
# Applications designed for fun (games, entertainment, socials, photos) are the most popular ones. Much less applications have any practical pruposes.
#
# **Can you recommend an app profile for the App Store market based on this frequency table alone? If there's a large number of apps for a particular genre, does that also imply that apps of that genre generally have a large number of users?**\
# The fact that there are many apps available for a purpose doesn't imply that people are actually using them.

# %% [markdown]
# ### Google store - Category Column

# %%
display_table(google_store_category_frequency_table)
# Out:
# FAMILY : 18.93
# GAME : 9.69
# TOOLS : 8.45
# BUSINESS : 4.59
# LIFESTYLE : 3.9
# PRODUCTIVITY : 3.89
# FINANCE : 3.7
# MEDICAL : 3.52
# SPORTS : 3.4
# PERSONALIZATION : 3.32
# COMMUNICATION : 3.24
# HEALTH_AND_FITNESS : 3.08
# PHOTOGRAPHY : 2.95
# NEWS_AND_MAGAZINES : 2.8
# SOCIAL : 2.66
# TRAVEL_AND_LOCAL : 2.34
# SHOPPING : 2.25
# BOOKS_AND_REFERENCE : 2.14
# DATING : 1.86
# VIDEO_PLAYERS : 1.79
# MAPS_AND_NAVIGATION : 1.4
# FOOD_AND_DRINK : 1.24
# EDUCATION : 1.17
# ENTERTAINMENT : 0.96
# LIBRARIES_AND_DEMO : 0.94
# AUTO_AND_VEHICLES : 0.93
# HOUSE_AND_HOME : 0.82
# WEATHER : 0.8
# EVENTS : 0.71
# PARENTING : 0.65
# ART_AND_DESIGN : 0.64
# COMICS : 0.62
# BEAUTY : 0.6

# %% [markdown]
# ### Google store - Genres Column
# **What is the most common genre? What is the next most common?**\
# The majority (98%) of the free, English apps are designed for Family, the next category (10%) is Games.
#
# **What is the general impression — are most of the apps designed for practical purposes (education, shopping, utilities, productivity, lifestyle) or more for entertainment (games, photo and video, social networking, sports, music)?**\
# Practical apps like Family, Tools, Business category are more common than fun ones like Games.

# %%
display_table(google_store_genres_frequency_table)
# Out:
# Tools : 8.44
# Entertainment : 6.07
# Education : 5.35
# Business : 4.59
# Productivity : 3.89
# Lifestyle : 3.89
# Finance : 3.7
# Medical : 3.52
# Sports : 3.46
# Personalization : 3.32
# Communication : 3.24
# Action : 3.1
# Health & Fitness : 3.08
# Photography : 2.95
# News & Magazines : 2.8
# Social : 2.66
# Travel & Local : 2.32
# Shopping : 2.25
# Books & Reference : 2.14
# Simulation : 2.04
# Dating : 1.86
# Arcade : 1.85
# Video Players & Editors : 1.77
# Casual : 1.75
# Maps & Navigation : 1.4
# Food & Drink : 1.24
# Puzzle : 1.13
# Racing : 0.99
# Role Playing : 0.94
# Libraries & Demo : 0.94
# Auto & Vehicles : 0.93
# Strategy : 0.91
# House & Home : 0.82
# Weather : 0.8
# Events : 0.71
# Adventure : 0.68
# Comics : 0.61
# Beauty : 0.6
# Art & Design : 0.6
# Parenting : 0.5
# Card : 0.44
# Casino : 0.43
# Trivia : 0.42
# Educational;Education : 0.39
# Educational : 0.37
# Board : 0.37
# Education;Education : 0.34
# Word : 0.26
# Casual;Pretend Play : 0.24
# Music : 0.2
# Puzzle;Brain Games : 0.18
# Racing;Action & Adventure : 0.17
# Entertainment;Music & Video : 0.17
# Casual;Brain Games : 0.14
# Casual;Action & Adventure : 0.14
# Arcade;Action & Adventure : 0.12
# Action;Action & Adventure : 0.1
# Educational;Pretend Play : 0.09
# Board;Brain Games : 0.09
# Simulation;Action & Adventure : 0.08
# Parenting;Education : 0.08
# Entertainment;Brain Games : 0.08
# Parenting;Music & Video : 0.07
# Educational;Brain Games : 0.07
# Casual;Creativity : 0.07
# Art & Design;Creativity : 0.07
# Education;Pretend Play : 0.06
# Role Playing;Pretend Play : 0.05
# Education;Creativity : 0.05
# Role Playing;Action & Adventure : 0.03
# Puzzle;Action & Adventure : 0.03
# Entertainment;Creativity : 0.03
# Entertainment;Action & Adventure : 0.03
# Educational;Creativity : 0.03
# Educational;Action & Adventure : 0.03
# Education;Music & Video : 0.03
# Education;Brain Games : 0.03
# Education;Action & Adventure : 0.03
# Adventure;Action & Adventure : 0.03
# Video Players & Editors;Music & Video : 0.02
# Sports;Action & Adventure : 0.02
# Simulation;Pretend Play : 0.02
# Puzzle;Creativity : 0.02
# Music;Music & Video : 0.02
# Entertainment;Pretend Play : 0.02
# Casual;Education : 0.02
# Board;Action & Adventure : 0.02
# Video Players & Editors;Creativity : 0.01
# Trivia;Education : 0.01
# Travel & Local;Action & Adventure : 0.01
# Tools;Education : 0.01
# Strategy;Education : 0.01
# Strategy;Creativity : 0.01
# Strategy;Action & Adventure : 0.01
# Simulation;Education : 0.01
# Role Playing;Brain Games : 0.01
# Racing;Pretend Play : 0.01
# Puzzle;Education : 0.01
# Parenting;Brain Games : 0.01
# Music & Audio;Music & Video : 0.01
# Lifestyle;Pretend Play : 0.01
# Lifestyle;Education : 0.01
# Health & Fitness;Education : 0.01
# Health & Fitness;Action & Adventure : 0.01
# Entertainment;Education : 0.01
# Communication;Creativity : 0.01
# Comics;Creativity : 0.01
# Casual;Music & Video : 0.01
# Card;Brain Games : 0.01
# Card;Action & Adventure : 0.01
# Books & Reference;Education : 0.01
# Art & Design;Pretend Play : 0.01
# Art & Design;Action & Adventure : 0.01
# Arcade;Pretend Play : 0.01
# Adventure;Education : 0.01

# %% [markdown]
# **What is the most common genre? What is the next most common?**\
# The majority (8%) of the free, English apps are Tools, the next category (6%) is Entertainment.
#
# **What is the general impression — are most of the apps designed for practical purposes (education, shopping, utilities, productivity, lifestyle) or more for entertainment (games, photo and video, social networking, sports, music)?**\
# Practical apps like Tools, Education, Business category are more common than fun ones like Entertainment, Lifestyle.

# %% [markdown]
# #### Comparison & conclusions
#
# The comparison of the number of free, English apps on Apple store and Google store show that most apps in Apple store are designed to have fun, while on Goole they are practical. However, it's not possible to determine which profile we should choose for our app based on this data. It only indicates what apps are available, not which ones are the most used.

# %% [markdown]
# Now it's time to analyze how many people actually use the apps from each genre. For Google store there is an `Installs` column available, but Apple store dataset doesn't have that. To be consistent, I'll use the column with the number of ratings for both stores.

# %% [markdown]
# ### Apple store - average of reviews per genre

# %%
def average_reviews_per_app_in_genre(raw_dataset, genre_column_index, reviews_column_index):
    reviews_per_genre = {}
    average_reviews_per_genre = {}

    for app in raw_dataset[1:]:
        genre = app[genre_column_index]
        reviews = int(app[reviews_column_index])

        if genre in reviews_per_genre:
            reviews_per_genre[genre]["sum_reviews"] += reviews
            reviews_per_genre[genre]["count_reviews"] += 1
        else:
            reviews_per_genre[genre] = {"sum_reviews": reviews, "count_reviews": 1}

    for genre, reviews in reviews_per_genre.items():
        average_reviews_per_genre[genre] = reviews["sum_reviews"] // reviews["count_reviews"]
    
    return average_reviews_per_genre

# %%
apple_average_reviews_per_genre = average_reviews_per_app_in_genre(apple_store_dataset, 11, 5)
display_table(apple_average_reviews_per_genre)
# Out:
# Navigation : 86090
# Reference : 74942
# Social Networking : 71548
# Music : 57326
# Weather : 52279
# Book : 39758
# Food & Drink : 33333
# Finance : 31467
# Photo & Video : 28441
# Travel : 28243
# Shopping : 26919
# Health & Fitness : 23298
# Sports : 23008
# Games : 22812
# News : 21248
# Productivity : 21028
# Utilities : 18684
# Lifestyle : 16485
# Entertainment : 14029
# Business : 7491
# Education : 7003
# Catalogs : 4004
# Medical : 612

# %% [markdown]
# We can see that the most reviewed app categories are: Navigation, Reference and Social Networking. Let's see what's inside of those categories.

# %%
def apple_show_apps_in_genre(genre):
    print(f"{genre} apps: ")
    for app in apple_store_dataset:
        app_genre = app[1]
        if app_genre == genre:
            print(app[0], ":", app[5])

apple_show_apps_in_genre("Navigation")
apple_show_apps_in_genre("Reference")
apple_show_apps_in_genre("Social Networking")
# Out:
# Navigation apps:
# Reference apps:
# Social Networking apps:

# %% [markdown]
# All of the most popular categories contain some apps that have significantly more reviews than others. In the `Navigation` category, we can see that `Geocaching` could be a potential niche to fill, however it seems like it might be a high effort to start such an app. In the `Reference` category, I can see a niche in the religion related applications. The Social Networking seems to be already saturated with popular apps, so it might be difficult to get our app to the wider public.

# %% [markdown]
# ### Google store - average of reviews per category

# %%
google_average_reviews_per_category = average_reviews_per_app_in_genre(google_store_dataset, 1, 3)
display_table(google_average_reviews_per_category)
# Out:
# COMMUNICATION : 995608
# SOCIAL : 965830
# GAME : 683839
# VIDEO_PLAYERS : 425350
# PHOTOGRAPHY : 403207
# TOOLS : 306086
# ENTERTAINMENT : 301752
# SHOPPING : 223887
# PERSONALIZATION : 181122
# WEATHER : 171250
# PRODUCTIVITY : 160634
# MAPS_AND_NAVIGATION : 142860
# TRAVEL_AND_LOCAL : 129484
# SPORTS : 116938
# FAMILY : 112996
# NEWS_AND_MAGAZINES : 93088
# BOOKS_AND_REFERENCE : 87995
# HEALTH_AND_FITNESS : 78094
# FOOD_AND_DRINK : 57478
# EDUCATION : 55791
# COMICS : 42585
# FINANCE : 38535
# LIFESTYLE : 33921
# HOUSE_AND_HOME : 26435
# ART_AND_DESIGN : 24699
# BUSINESS : 24239
# DATING : 21953
# PARENTING : 16378
# AUTO_AND_VEHICLES : 14140
# LIBRARIES_AND_DEMO : 10925
# BEAUTY : 7476
# MEDICAL : 3727
# EVENTS : 2555

# %%
def google_show_apps_in_genre(genre):
    print(f"{genre} apps: ")
    for app in google_store_dataset:
        app_genre = app[1]
        if app_genre == genre:
            print(app[0], ":", app[3])

google_show_apps_in_genre("COMMUNICATION")
google_show_apps_in_genre("SOCIAL")
google_show_apps_in_genre("GAME")
# Out:
# COMMUNICATION apps:
# Messenger – Text and Video Chat for Free : 56646578
# WhatsApp Messenger : 69119316
# Messenger for SMS : 125257
# Google Chrome: Fast & Secure : 9643041
# Messenger Lite: Free Calls & Messages : 1429038
# Gmail : 4604483
# Hangouts : 3419513
# Viber Messenger : 11335481
# My Tele2 : 158679
# Firefox Browser fast & private : 3075118
# Yahoo Mail – Stay Organized : 4188345
# imo beta free calls and text : 659395
# imo free video calls and chat : 4785988
# Contacts : 66602
# Call Free – Free Call : 30209
# Web Browser & Explorer : 36901
# Opera Mini - fast web browser : 5150801
# Browser 4G : 192948
# MegaFon Dashboard : 99559
# ZenUI Dialer & Contacts : 437674
# Cricket Visual Voicemail : 13698
# Opera Browser: Fast and Secure : 2473795
# TracFone My Account : 20769
# Firefox Focus: The privacy browser : 36981
# Google Voice : 171052
# Chrome Dev : 63576
# Xperia Link™ : 45487
# TouchPal Keyboard - Fun Emoji & Android Keyboard : 615381
# Who : 2451093
# Skype Lite - Free Video Call & Chat : 33053
# WeChat : 5387631
# UC Browser Mini -Tiny Fast Private & Secure : 3648765
# WhatsApp Business : 137144
# My magenta : 42370
# Android Messages : 781810
# Telegram : 3128611
# Google Duo - High Quality Video Calls : 2083237
# Puffin Web Browser : 541661
# Seznam.cz : 46702
# Antillean Gold Telegram (original version) : 2939
# AT&T Visual Voicemail : 13761
# GMX Mail : 258556
# Omlet Chat : 40751
# UC Browser - Fast Download Private & Secure : 17714850
# My Vodacom SA : 25021
# Microsoft Edge : 27187
# Hangouts Dialer - Call Phones : 122512
# Talkatone: Free Texts, Calls & Phone Number : 132015
# Calls & Text by Mo+ : 83239
# free video calls and chat : 594728
# Skype - free IM & video calls : 10484169
# GO SMS Pro - Messenger, Free Themes, Emoji : 2876500
# Messaging+ SMS, MMS Free : 28238
# chomp SMS : 335646
# Glide - Video Chat Messenger : 350154
# Text SMS : 349384
# Google Allo : 347086
# Talkray - Free Calls & Texts : 244863
# LINE: Free Calls & Messages : 10790289
# GroupMe : 330761
# mysms SMS Text Messaging Sync : 37320
# BBM - Free Calls & Messages : 12843436
# KakaoTalk: Free Calls & Text : 2546549
# 2ndLine - Second Phone Number : 15880
# CM Browser - Ad Blocker , Fast Download , Privacy : 2265084
# Ninesky Browser : 42925
# Dolphin Browser - Fast, Private & Adblock🐬 : 2511130
# Ghostery Privacy Browser : 13100
# InBrowser - Incognito Browsing : 27156
# Web Browser for Android : 55110
# DU Browser—Browse fast & fun : 1133539
# Lightning Web Browser : 12578
# Web Browser : 10965
# Contacts+ : 190613
# ExDialer - Dialer & Contacts : 125232
# PHONE for Google Voice & GTalk : 72065
# Safest Call Blocker : 27540
# Full Screen Caller ID : 104990
# Hiya - Caller ID & Block : 177703
# Mr. Number-Block calls & spam : 177263
# Should I Answer? : 237468
# RocketDial Dialer & Contacts : 32254
# CallApp: Caller ID, Blocker & Phone Call Recorder : 483782
# Whoscall - Caller ID & Block : 552635
# CIA - Caller ID & Call Blocker : 60308
# Calls Blacklist - Call Blocker : 457283
# Call Control - Call Blocker : 93825
# True Contact - Real Caller ID : 32283
# Video Caller Id : 15287
# Sync.ME – Caller ID & Block : 205739
# Burner - Free Phone Number : 14873
# Truecaller: Caller ID, SMS spam blocking & Dialer : 7820775
# Caller ID + : 9498
# K-9 Mail : 88427
# myMail – Email for Hotmail, Gmail and Outlook Mail : 305218
# Email TypeApp - Mail App : 183374
# All Email Providers : 20901
# Newton Mail - Email App for Gmail, Outlook, IMAP : 122595
# GO Notifier : 124346
# Mail.Ru - Email App : 837842
# Mail1Click - Secure Mail : 255
# Daum Mail - Next Mail : 41420
# mail.com mail : 44706
# SolMail - All-in-One email app : 23707
# Vonage Mobile® Call Video Text : 29208
# JusTalk - Free Video Calls and Fun Video Chat : 191032
# Azar : 1092337
# LokLok: Draw on a Lock Screen : 14766
# Discord - Chat for Gamers : 305347
# AntennaPict β : 15439
# Kik : 2451136
# K-@ Mail - Email App : 1760
# K-9 Material (unofficial) : 64
# M star Dialer : 400
# Free WiFi Connect : 167229
# m:go BiH : 559
# N-Com Wizard : 960
# Opera Mini browser beta : 401530
# Psiphon Pro - The Internet Freedom VPN : 298041
# ICQ — Video Calls & Chat Messenger : 697939
# AT&T Messages for Tablet : 3044
# T-Mobile DIGITS : 1820
# Portable Wi-Fi hotspot : 138129
# AT&T Call Protect : 6454
# U - Webinars, Meetings & Messenger : 6601
# /u/app : 573
# [verify-U] VideoIdent : 83
# WhatsCall Free Global Phone Call App & Cheap Calls : 1130966
# X Browser : 142
# Free Adblocker Browser - Adblock & Popup Blocker : 152470
# Adblock Browser for Android : 121113
# Adblock Plus for Samsung Internet - Browse safe. : 8769
# Ad Blocker Turbo - Adblocker Browser : 107
# Brave Browser: Fast AdBlocker : 40241
# AG Contacts, Lite edition : 185
# Oklahoma Ag Co-op Council : 0
# Bee'ah Employee App : 4
# tournaments and more.aj.2 : 0
# Aj.Petra : 5
# AK Phone : 9
# PlacarTv Futebol Ao Vivo : 2063
# WiFi Access Point (hotspot) : 684
# Access Point Names : 138
# ClanHQ : 560
# Ear Agent: Super Hearing : 42329
# AU Call Blocker - Block Unwanted Calls Texts 2018 : 16
# Baby Monitor AV : 1434
# AV Phone : 4
# AW - free video calls and chat : 7317
# Katalogen.ax : 1
# AZ Browser. Private & Download : 1520
# BA SALES : 0
# BD Data Plan (3G & 4G) : 10341
# BD Internet Packages (Updated) : 474
# BD Dialer : 29
# BD Live Call : 7
# Best Browser BD social networking : 6
# Traffic signs BD : 7
# BF Browser by Betfilter - Stop Gambling Today! : 39
# My BF App : 141
# BH Mail : 7
# Zalo – Video Call : 1042170
# BJ - Confidential : 0
# BK Chat : 6
# Of the wall Arapaho bk : 0
# AC-BL : 0
# DMR BrandMeister Tool : 78
# BBMoji - Your personalized BBM Stickers : 8827
# BN MALLORCA Radio : 23
# BQ Partners : 0
# BS-Mobile : 1
# ATC Unico BS : 10
# BT One Voice mobile access : 32
# BT Messenger : 97
# BT One Phone Mobile App : 33
# SW-100.tch by Callstel : 1926
# BT MeetMe with Dolby Voice : 437
# Bluetooth Auto Connect : 20829
# AudioBT: BT audio GPS/SMS/Text : 198
# BV : 3
# Feel Performer : 62
# Tiny Call Confirm : 22782
# CB Radio Chat - for friends! : 17998
# CB On Mobile : 901
# Virtual Walkie Talkie : 21785
# Channel 19 : 916
# Cb browser : 5
# CF Chat: Connecting Friends : 5
# retteMi.ch : 31
# CJ Browser - Fast & Private : 5
# CJ DVD Rentals : 5
# CK Call NEW : 0
# CM Transfer - Share any files with friends nearby : 71740
# mail.co.uk Mail : 21
# ClanPlay: Community and Tools for Gamers : 34443
# CQ-Mobile : 10
# CQ-Alert : 3
# QRZ Assistant : 1044
# Pocket Prefix Plus : 192
# Ham Radio Prefixes : 218
# CS Customizer : 25
# CS Browser | #1 & BEST BROWSER : 52
# CS Browser Beta : 125
# My Vodafone (GR) : 12667
# IZ2UUF Morse Koch CW : 649
# C W Browser : 14
# CW Bluetooth SPP : 3
# CW BLE Peripheral Simulator : 2
# Morse Code Reader : 1436
# Learn Morse Code - G0HYN Learn Morse : 27
# Ring : 517
# Hyundai CX Conference : 0
# Cy Messenger : 4
# Amadeus GR & CY : 4
# Hlášenírozhlasu.cz : 0
# SMS Sender - sluzba.cz : 12
# WEB.DE Mail : 226541
# Your Freedom VPN Client : 74497
# Rádio Sol Nascente DF : 12
# DG Card : 0
# DK Browser : 1
# cluster.dk : 49
# DK TEL Dialer : 0
# DM for WhatsApp : 25
# DM Talk New : 3
# DM - The Offical Messaging App : 0
# DM Tracker : 11
# Call Blocker & Blacklist : 6
# ReadyOp DT : 8
# Caller ID & Call Block - DU Caller : 93930
# BlueDV AMBE : 0
# DW Contacts & Phone & Dialer : 21186
# Deaf World DW : 298
# Ham DX Cluster & Spots Finder : 115
# Mircules DX Cluster Lite : 51
# 3G DZ Configuration : 488
# chat dz : 8
# love sms good morning : 10
# Goodbox - Mega App : 3429
# Call Blocker - Blacklist, SMS Blocker : 30350
# [EF]ShoutBox : 3
# Eg Call : 91
# ei : 2
# EJ messenger : 1
# Ek IRA : 0
# Orfox: Tor Browser for Android : 44233
# EO Mumbai : 0
# EP RSS Reader : 4
# Voxer Walkie Talkie Messenger : 230564
# ES-1 : 6
# EU Council : 7
# Council Voting Calculator : 33
# Have your say on Europe : 19
# Programi podrške EU : 0
# Inbox.eu : 98
# Everbridge : 497
# Best Auto Call Recorder Free : 7
# EZ Wifi Notification : 260
# Test Server SMS FA : 0
# Lite for Facebook Messenger : 76498
# FC Browser - Focus Privacy Browser : 26
# EHiN-FH conferenceapp : 5
# Carpooling FH Hagenberg : 0
# Wi-Fi Auto-connect : 15036
# Talkie - Wi-Fi Calling, Chats, File Sharing : 4838
# WeFi - Free Fast WiFi Connect & Find Wi-Fi Map : 13469
# Sat-Fi : 97
# Portable Wi-Fi hotspot Free : 1711
# TownWiFi | Wi-Fi Everywhere : 2372
# Jazz Wi-Fi : 49
# Sat-Fi Voice : 37
# Free Wi-fi HotspoT : 382
# FN Web Radio : 0
# FNH Payment Info : 0
# MARKET FO : 0
# FO OP St-Nazaire : 1
# FO SODEXO : 0
# FO RCBT : 5
# FO Interim : 1
# FO PSA Sept-Fons : 2
# FO AIRBUS TLSE : 4
# FO STELIA Méaulte : 2
# FO AIRBUS Nantes : 0
# FP Connect : 0
# FreedomPop Messaging Phone/SIM : 9894
# FP Live : 0
# HipChat - beta version : 1035
# SOCIAL apps:
# Facebook : 78158306
# Instagram : 66577446
# Facebook Lite : 8606259
# Messages, Text and Video Chat for Messenger : 49580
# Tumblr : 2955326
# All Social Networks : 22650
# Snapchat : 17015352
# Social network all in one 2018 : 1403
# Pinterest : 4305441
# TextNow - free text + calls : 441189
# Google+ : 4831125
# The Messenger App : 4919
# Messenger Pro : 13762
# Free Messages, Video, Chat,Text for Messenger Plus : 6086
# Telegram X : 70616
# The Video Messenger App : 1200
# Jodel - The Hyperlocal App : 76480
# Who Viewed My Facebook Profile - Stalkers Visitors : 273244
# Hide Something - Photo, Video : 225103
# Love Sticker : 33177
# Web Browser & Fast Explorer : 54768
# LiveMe - Video chat, new friends, and make money : 457197
# VidStatus app - Status Videos & Status Downloader : 25562
# Love Images : 16404
# Web Browser ( Fast & Secure Web Explorer) : 2508
# SPARK - Live random video chat & meet new people : 79658
# Golden telegram : 374
# Amino: Communities and Chats : 1264084
# Facebook Local : 4751
# Meet – Talk to Strangers Using Random Video Chat : 60562
# MobilePatrol Public Safety App : 22695
# 💘 WhatsLov: Smileys of love, stickers and GIF : 22098
# Phone Tracker : Family Locator : 231446
# HTC Social Plugin - Facebook : 13223
# Periscope - Live Video : 479939
# Quora : 313633
# Kate Mobile for VK : 540930
# Family GPS tracker KidControl + GPS by SMS Locator : 57146
# LinkedIn : 1225367
# Moment : 19583
# Text Me: Text Free, Call Free, Second Phone Number : 344921
# Meetup : 79130
# Text Free: WiFi Calling App : 83488
# Badoo - Free Chat & Dating App : 3781770
# Text free - Free Text + Call : 315441
# textPlus: Free Text & Calls : 382121
# Free phone calls, free texting SMS on free number : 412888
# Tango - Live Video Broadcast : 3806669
# MeetMe: Chat & Meet New People : 1259894
# Tagged - Meet, Chat & Dating : 486830
# ooVoo Video Calls, Messaging & Stories : 1157004
# SayHi Chat, Meet New People : 423138
# Whisper : 205803
# Tapatalk - 100,000+ Forums : 285820
# Blogger : 138026
# Bloglovin' : 8936
# Blogaway for Android (Blogger) : 4253
# TwitCasting Live : 14835
# Stream - Live Video Community : 6388
# YouNow: Live Stream Video Chat : 309872
# Mirrativ: Live Stream Any App : 17955
# Nextdoor - Local neighborhood news & classifieds : 51504
# SKOUT - Meet, Chat, Go Live : 1064076
# Banjo : 58341
# We Heart It : 637309
# Timehop : 161610
# Frontback - Social Photos : 19446
# Path : 1520959
# Couple - Relationship App : 33249
# POF Free Dating App : 1175815
# LOVOO : 852455
# Jaumo Dating, Flirt & Live Video : 900064
# Patook - make platonic friends : 3677
# Zello PTT Walkie Talkie : 695613
# magicApp Calling & Messaging : 207712
# Dating App, Flirt & Chat : W-Match : 175722
# uCiC- Videos and Photos on demand : 2052
# Mico- Stranger Chat Random video Chat, Live, Meet : 624557
# Waplog - Free Chat, Dating App, Meet Singles : 522018
# Tik Tok - including musical.ly : 5637451
# B-Messenger Video Chat : 12495
# BIGO LIVE - Live Stream : 2349421
# Greeting Cards & Wishes : 17350
# Share G - Images Sharing - Wallpapers App : 120
# H letter images : 17
# Instachat 😜 : 80987
# Fame Boom for Real Followers, Likes : 896118
# FollowMeter for Instagram : 90082
# Mali J : 185
# KDRAMA Amino for K-Drama Fans : 4046
# KPOP Amino for K-Pop Entertainment : 19047
# EXO-L Amino for EXO Fans : 5677
# Verdad o Reto : 826
# pixiv : 86956
# Join R, Community Engagement : 144
# U LIVE – Video Chat & Stream : 67611
# See U - Random video chat, video chat : 568
# What U See : 712
# U-Report : 241
# Meet U - Get Friends for Snapchat, Kik & Instagram : 4435
# VMate Lite - Funny Short Videos Social Network : 903
# V Bucks ProTips New : 594
# i-share AF/KLM (AFKL ishare) : 2
# Eternal Light AG : 30
# Message AI - Write Better Messages (Free) : 3
# Jamaa Amino for Animal Jam : 3873
# Legend - Animate Text in Video : 228737
# GUYZ - Gay Chat & Gay Dating : 41269
# eChallan Andhra Pradesh (AP) : 5
# Snaappy – 3D fun AR core communication platform : 16801
# Undertale AU Amino : 5369
# Au Pair : 58
# Media Sosial TNI AU : 88
# BA 3 Banjarmasin : 2
# iCard BD Plus : 2
# Movement BE : 20
# YAY - TBH : 2520
# Find My Friends : 305367
# BG LINKED (BGLINKED) : 22
# Zdravei.BG : 6
# BGKontakti London BG Kontakti : 4
# BGKontakti Bayern BG Kontakti : 32
# BGKontakti Vienna BG Kontakti : 111
# Discípulos em BH : 24
# BH Connect : 0
# Gayvox - Gay Lesbian Bi Dating : 3640
# Grindr - Gay chat : 284795
# Lesbian Chat & Dating - SPICY : 63765
# Alumni BJ : 2
# VK : 5793284
# BK Traffic Control cum Chart : 549
# Daily Murli Saar Widget : 308
# Myjob@BM : 1
# bm-Events : 0
# BOO! - Next Generation Messenger : 20675
# Wishbone - Compare Anything : 51569
# BR Chat Bot : 16
# Br Browser : 29
# Dr B R Ambedkar (Jai Bhim) : 2068
# Dr. B.R.Ambedkar : 1902
# Black Social : 22
# BT Communicator : 32
# BT Dating -Find your match, help cupid, be social : 158
# Fiesta by Tango - Find, Meet and Make New Friends : 112223
# Evasion.bz : 8
# CB Heroes : 5
# CG Districts : 14
# Digi-TV.ch : 62
# Students.ch : 5
# CJ Gospel Hour : 7
# Pekalongan CJ : 0
# Hashtags For Likes.co : 420
# CP Dialer : 64
# C.P. CERVANTES (TOBARRA) : 0
# Cyprus Police : 226
# Rande.cz : 398
# signály.cz : 38
# DB Event App : 37
# DC Comics Amino : 117
# DF BugMeNot : 7
# Noticias DF : 2
# Daddyhunt: Gay Dating : 6450
# HOLLA Live: Meet New People via Random Video Chat : 216513
# Dating.dk : 2111
# DK Murali : 65
# GirlTalk.dk : 3
# +Download 4 Instagram Twitter : 40467
# DM Me - Chat : 90
# DM for IG 😘 - Image & Video Saver for Instagram : 55
# Auto DM for Twitter 🔥 : 44
# DM Storage (for twitter) : 6
# Fake Chat (Direct Message) : 5985
# Otto DM : 0
# DN Blog : 20
# DP and Status for WhatsApp 2018 : 787
# Dp For Whatsapp : 39
# Profile Pictures and DP for Whatsapp : 48
# Dp for Facebook : 56
# Best DP and Status : 93
# Instant DP Downloader for Instagram : 38
# DP Display Pictures Life Quotes Motivational GM : 39
# Qeek for Instagram - Zoom profile insta DP : 12111
# DV Statistics : 6
# DW Streaming : 0
# News Dz : 3
# quran-DZ : 0
# TN e Sevai TN EB Bill Patta Citta EC Birth All Hub : 23
# TNEB Bill Online Payment (Tamil) : 7
# UP EB Bill Payment & Details : 3
# TN EC Online New : 7
# TN Patta /Chitta /EC New : 5
# EG Way Life : 0
# Equestria Amino for MLP : 8369
# Ek Maratha : 725
# Hum Ek Hain 2.02 : 2
# Sabka Malik Ek Sai : 17
# EO RAIPUR : 1
# Anime et Manga Amino en Français : 3782
# Hornet - Gay Social Network : 163679
# European Solidarity Corps : 9
# Reisedealz.eu : 0
# Eddsworld Amino : 3071
# Rejoin Your Ex : 0
# Amleen Ey : 0
# Coupe Adhémar EY 2017 : 6
# EZ Video Download for Facebook : 34079
# Messenger Messenger : 38826
# Facebook Creator : 3895
# Swift for Facebook Lite : 9562
# Friendly for Facebook : 42621
# Faster for Facebook Lite : 24456
# Puffin for Facebook : 10743
# Profile Tracker - Who Viewed My Facebook Profile : 37090
# Pink Color for Facebook : 5285
# Messenger : 68025
# Stickers for Imo, fb, whatsapp : 214
# Downloader plus for FB : 4
# MB Notifications for FB (Free) : 3047
# Phoenix - Facebook & Messenger : 9606
# Faster Social for Facebook : 1236
# Check Your Visitors on FB ? : 40
# Stickers for Facebook : 11066
# Lite Messenger for Facebook Lite : 108
# Mini for Facebook lite : 260
# FB Advanced Search : 2
# funny Image Comments for FB : 19
# Unlimited Group Links - Whatsapp, FB, Telegram : 44
# FCB Connect - FC Barcelona : 795
# Frases Cristianas de Esperanza y Fe : 2
# FutureNet your social app : 2093
# Alarm.fo – choose your info : 19
# FunForMobile Ringtones & Chat : 68358
# Chat For Strangers - Video Chat : 622
# Fr Daoud Lamei : 2036
# Naruto & Boruto FR : 7
# Frim: get new friends on local chat rooms : 88486
# GAME apps:
# Subway Surfers : 27725352
# Candy Crush Saga : 22430188
# slither.io : 5235294
# Clash Royale : 23136735
# Temple Run 2 : 8119154
# Pou : 10486018
# Helix Jump : 1500999
# Block Puzzle : 59907
# Angry Birds Rio : 2610680
# Plants vs. Zombies FREE : 4067651
# Sonic Dash : 3778921
# Candy Crush Soda Saga : 6199095
# Zombie Hunter King : 10538
# Clash of Clans : 44893888
# Kick the Buddy : 1004709
# Block Puzzle Classic Legend ! : 17044
# PAC-MAN : 685981
# Super Jim Jump - pixel 3d : 10460
# 8 Ball Pool : 14201891
# Magic Tiles 3 : 592504
# Bubble Witch 3 Saga : 1732263
# Word Search : 344585
# Granny : 1138239
# Angry Birds Classic : 5566908
# Flow Free : 1295625
# Race the Traffic Moto : 270687
# Fishdom : 2158580
# Galaxy Attack: Alien Shooter : 506593
# Zombie Tsunami : 4921451
# Bubble Shooter 2 : 23043
# Candy Crush Jelly Saga : 1300619
# Hill Climb Racing : 8923847
# Gardenscapes : 4129665
# Marble - Temple Quest : 42053
# Shooting King : 257724
# Zombie Catchers : 990796
# Geometry Dash World : 760628
# My Talking Angela : 9883367
# Cut the Rope FULL FREE : 2123793
# Sniper 3D Gun Shooter: Free Shooting Games - FPS : 7674252
# Cooking Fever : 3198176
# Toon Blast : 1351771
# Score! Hero : 5419676
# Toy Blast : 1889582
# Miraculous Ladybug & Cat Noir - The Official Game : 185382
# Wordscapes : 230849
# Garena Free Fire : 5534114
# Bowmasters : 1536349
# My Talking Tom : 14892469
# Jungle Marble Blast : 18985
# Rider : 655145
# Roll the Ball® - slide puzzle : 1385093
# Talking Tom Gold Run : 2698889
# Pixel Art: Color by Number Game : 1125566
# Dream League Soccer 2018 : 9883806
# Fruits Bomb : 74695
# Traffic Racer : 5387781
# Hill Climb Racing 2 : 2750645
# Knife Hit : 462614
# Block Craft 3D: Building Simulator Games For Free : 946926
# Farm Fruit Pop: Party Time : 9305
# Love Balls : 360630
# Hungry Shark Evolution : 6074627
# Piano Tiles 2™ : 8118880
# Pokémon GO : 10424925
# Paint Hit : 37023
# Snake VS Block : 422244
# Rolly Vortex : 98123
# Woody Puzzle : 21262
# Stack Jump : 118253
# Color by Number – New Coloring Book : 142308
# The Cube : 70226
# Extreme Car Driving Simulator : 2251012
# Bricks n Balls : 30253
# The Fish Master! : 15763
# Color Road : 84911
# Draw In : 46416
# PLANK! : 7196
# Looper! : 48256
# Trivia Crack : 6427773
# Will it Crush? : 25825
# Tomb of the Mask : 55380
# Baseball Boy! : 148177
# PUBG MOBILE : 3716278
# Hello Stars : 101686
# Run Sausage Run! : 276105
# Tank Stars : 174755
# Hole.io : 145353
# Mini Golf King - Multiplayer Game : 531458
# Flip the Gun - Simulator Game : 195558
# Mad Skills BMX 2 : 29940
# MMX Hill Dash 2 – Offroad Truck, Car & Bike Racing : 41975
# Word Link : 216675
# Last Day on Earth: Survival : 2311785
# Partymasters - Fun Idle Game : 541144
# Harry Potter: Hogwarts Mystery : 1107310
# Offroad Outlaws : 29168
# Grim Soul: Dark Fantasy Survival : 189773
# DRAGON BALL LEGENDS : 338742
# Disney Heroes: Battle Mode : 102107
# Homescapes : 3093932
# New YAHTZEE® With Buddies Dice Game : 42079
# Word Crossy - A crossword game : 240416
# MLB TAP SPORTS BASEBALL 2018 : 32506
# Hero Hunters : 70747
# Cooking Madness - A Chef's Restaurant Games : 358817
# Ice Crush 2018 - A new Puzzle Matching Adventure : 15403
# TerraGenesis - Space Colony : 38957
# Merge Dragons! : 214819
# SHADOWGUN LEGENDS : 100609
# RULES OF SURVIVAL : 1343866
# Mafia City : 168717
# Cash, Inc. Money Clicker Game & Business Adventure : 549720
# Dino War: Rise of Beasts : 18996
# Tokyo Ghoul: Dark War : 25094
# Last Shelter: Survival : 93033
# Guns of Glory : 120592
# Lineage 2: Revolution : 187972
# Final Fantasy XV: A New Empire : 484981
# Girls' Frontline : 2055
# Chapters: Interactive Stories : 73539
# Honkai Impact 3rd : 59017
# Master of Eternity(MOE) : 5829
# Angry Birds 2 : 3883589
# The Sims™ FreePlay : 931595
# Best Fiends - Free Puzzle Game : 1480189
# MARVEL Contest of Champions : 2468915
# Jurassic World™ Alive : 309176
# Choices: Stories You Play : 807338
# Solitaire TriPeaks : 446434
# The Walking Dead: Road to Survival : 522466
# Hustle Castle: Fantasy Kingdom : 584126
# Might & Magic: Elemental Guardians : 32551
# Game of Thrones: Conquest™ : 90218
# Love Nikki-Dress UP Queen : 212524
# Summoners War : 2045554
# FINAL FANTASY BRAVE EXVIUS : 745684
# Fate/Grand Order (English) : 16601
# Lords Mobile: Battle of the Empires - Strategy RPG : 3057481
# War and Order : 224514
# Yes day : 10055521
# Jewels Star: OZ adventure : 21892
# Sweet Fruit Candy : 197540
# Shoot Bubble - Fruit Splash : 29445
# Doodle Jump : 1083571
# Crossy Road : 4230886
# Swamp Attack : 2119235
# Earn to Die 2 : 1327269
# Hungry Shark World : 1243017
# Dude Perfect 2 : 401648
# Shadow Fight 2 : 10981850
# Alto's Adventure : 515657
# DEER HUNTER 2018 : 955656
# DEAD TARGET: FPS Zombie Apocalypse Survival Games : 1468638
# Cover Fire: offline shooting games for free : 725897
# Anger of stick 5 : zombie : 549039
# CATS: Crash Arena Turbo Stars : 1559650
# Soul Knight : 292164
# Major Mayhem : 520962
# DINO HUNTER: DEADLY SHORES : 1381820
# Extreme Match : 696
# Power Rangers Dino Charge : 194969
# Zombie Hunter: Post Apocalypse Survival Games : 327599
# Agar.io : 3816799
# Battlelands Royale : 105620
# Once Upon a Tower : 37139
# TEKKEN™ : 147791
# diep.io : 347883
# Arrow.io : 343263
# BEYBLADE BURST app : 216849
# Dragon Hills : 354373
# Bus Rush: Subway Edition : 753043
# Tiny Archers : 80678
# Metal Soldiers 2 : 153649
# Runner 3d like : 559
# War Robots : 3073251
# Dinosaur Simulator: Dino World : 26649
# GUNSHIP BATTLE: Helicopter 3D : 2151039
# Quiz: Logo game : 306764
# Jewels Legend - Match 3 Puzzle : 280098
# Bubble Shooter Genies : 26985
# Blossom Blast Saga : 1125438
# Candy Bomb : 42145
# Gems or jewels ? : 171448
# Power Pop Bubbles : 104303
# Jewels classic Prince : 47644
# Fruit Block - Puzzle Legend : 125647
# Bubble Shooter Space : 4355
# 1LINE – One Line with One Touch : 214878
# Stick War: Legacy : 811040
# Marble Woka Woka 2018 - Bubble Shooter Match 3 : 155186
# Super Jabber Jump 3 : 34494
# Rush : 260651
# Jetpack Joyride : 4638163
# Racing in Car 2 : 234589
# Rope Hero Return of a Legend : 9951
# Draw a Stickman: EPIC 2 Free : 213340
# UNO ™ & Friends : 1728557
# 4 in a Row : 4257
# Super Mario Run : 1221896
# STARDOM: THE A-LIST : 152658
# Glow Hockey : 1703479
# Asphalt 8: Airborne : 8389714
# Lep's World 2 🍀🍀 : 798522
# Law of Creation: A Playable Manga : 13118
# Real City Car Driver : 413609
# Rolling Sky : 1117212
# 4 in a row : 47698
# Four In A Line Free : 133195
# Draw A Stickman : 29265
# Four In A Line : 22191
# Cardi B Piano Game : 50
# MORTAL KOMBAT X : 3039889
# ► MultiCraft ― Free Miner! 👍 : 1305050
# Pixel Gun 3D: Survival shooter & Battle Royale : 4487182
# Perfect Piano : 828489
# Critical Ops : 1397944
# FRONTLINE COMMANDO: D-DAY : 1736105
# Fruit Ninja® : 5091448
# Beach Buggy Blitz : 640974
# Vector : 3058687
# Dr. Driving : 4972230
# D Day World War II Commando Survival Shooting : 951
# Geometry Dash Meltdown : 1591129
# Bike Race Free - Top Motorcycle Racing Games : 2586261
# Smash Hit : 4147718
# Temple Run : 4000433
# Super Car F. Mod for MCPE : 214
# Gangstar Vegas - mafia game : 4830407
# Rolling G Sky : 2065
# G-Switch 2 : 12683
# G-Switch 3 : 3656
# G-Switch : 4116
# Radial-G : Infinity : 517
# Geometry Dash Lite : 6181640
# Car Driving Simulator Drift : 19816
# RC City Police Heavy Traffic Racer : 3250
# Motorbike Driving Simulator 3D : 178723
# Helix : 2454
# Solitaire! : 403911
# iGun Pro -The Original Gun App : 249308
# NinJump : 421000
# Fidget Spinner : 307398
# J Balvin Piano Tiles : 6
# Guess the song of J Balvin : 28
# J-Stars Victory VS Guide : 609
# KIM KARDASHIAN: HOLLYWOOD : 1017408
# Magic Tiles - TWICE Edition (K-Pop) : 2351
# Magic Tiles - Blackpink Edition (K-Pop) : 4304
# Korean Dungeon: K-Word 1000 : 703
# Lep's World 🍀 : 696019
# Ant Smasher by Best Cool & Fun Games : 1185148
# Cheating Tom 3 - Genius School : 90415
# M3-X5-X6-M-İ3-İ8 RACİNG 2018 : 596
# M-acceleration 3D Car Racing : 1202
# Super Hero M Craft Run : 303
# Don't Hug Me I'm So Scared : 901
# Rope'n'Fly 4 : 234606
# Cops N Robbers - FPS Mini Game : 156862
# Cops N Robbers 2 : 63680
# Hide N Seek : Mini Game : 4719
# Rope'n'Fly 3 - Dusk Till Dawn : 166033
# Drag'n'Boom : 133180
# Cops N Robbers : 37789
# Mopar Drag N Brag : 30630
# Draw N Guess Multiplayer : 29505
# Rock N' Cash Casino Slots -Free Vegas Slot Games : 6187
# Rock n Roll Music Quiz Game : 80
# Drink-O-Tron The Drinking Game : 140
# The Maze Runner : 428268
# The Q - Live Trivia Game Network : 1486
# Q*bert: Rebooted : 13788
# Gun Shoot War Q : 26893
# DJMAX TECHNIKA Q - Music Game : 21107
# Stupid Zombies : 464900
# Crime Wars S. Andreas : 5785
# Dino T-Rex : 69115
# U-48 Submarine Commander Free : 4575
# Identity V : 109263
# V for Voodoo : 16876
# Sin City Crime Simulator V - Gangster : 2113
# The Gang Sniper V. Pocket Edition. : 6121
# San Andreas: Gang Crime V : 2399
# Grand Stickman Cover V : 1744
# Words With Friends Classic : 1704112
# Draw Something Classic : 1092106
# Extreme X Ray Robot Stunts : 10806
# Casino X - Free Online Slots : 30515
# X-WOLF : 4878
# Hero Fighter X : 24210
# Slendrina X : 12736
# Robocar X Ray : 3432
# Space X: Sky Wars of Air Force : 10748
# Real Gangster Crime : 285814
# Gangster Town : 74842
# Rope Hero 3 : 45871
# Experiment Z - Zombie : 229329
# Z Champions : 96028
# WithstandZ - Zombie Survival! : 121612
# Zombie War Z : Hero Survival Rules : 1987
# DRAGON BALL Z DOKKAN BATTLE : 650114
# Cube Z (Pixel Zombies) : 41444
# GALAK-Z: Variant Mobile : 145
# Reload: The Z-Team : 1655
# Rage Z: Multiplayer Zombie FPS Online Shooter : 11258
# Pixel Z Gunner 3D - Battle Survival Fps : 11408
# Saiyan Z: Super SSJ Ultimate Combat : 306
# Mini DAYZ: Zombie Survival : 94661
# Route Z : 24697
# Dragon X Adventure: Warrior Z : 8537
# Ultimate Fighter Z : 180
# Angry Birds Friends : 829753
# Angry Birds Go! : 3846378
# Angry Birds Star Wars : 1218055
# Solitaire: Decked Out Ad Free : 37302
# AE Jewels 2: Island Adventures : 652
# AE Bingo: Offline Bingo Games : 61746
# AE Jewels : 960
# AE Spider Solitaire : 17263
# AE Coin Mania : Arcade Fun : 30002
# Mupen64+AE FREE (N64 Emulator) : 41759
# AE Lucky Fishing : 18277
# AE Video Poker : 721
# AE Solitaire : 1776
# AE Blackjack : 1417
# AE Gun Ball: arcade ball games : 8581
# AE 3D MOTOR :Racing Games Free : 74902
# AE GTO Racing : 6988
# AE 3D Moto 3 : 2588
# AE FreeCell : 358
# AE City Jump : 804
# AE Angry Chef : 533
# AE Master Moto : 17876
# AE Fishing Hunter : 14
# Gun Strike Shoot : 94761
# AG Drive 3D : 164
# VR AG Racing for Cardboard : 13
# AH-1 Viper Cobra Ops - helicopter flight simulator : 1088
# Ah! Coins : 256
# Baby Game Animal Jam Free : 9
# Blackjack aj Poker : 8
# Puppy Shooting an AK-47: Platformer Zombie Game : 21
# Crisis Action: 2018 NO.1 FPS : 807226
# AK-47 3D : 91
# AK-47 Assult Rifle: Gun Shooting Simulator Game : 1
# Counter Terrorist Attack : 145931
# AK Blackjack : 4
# GUN ZOMBIE : 243121
# Shoot Strike War Fire : 82827
# I Am Innocent : 208501
# What Am I? - Brain Teasers : 4537
# Who am I? (Biblical) : 5849
# Vikings: an Archer's Journey : 10256
# Draw a Stickman: EPIC Free : 210317
# THE KING OF FIGHTERS-A 2012(F) : 406511
# Fast like a Fox : 104389
# Ao Oni2 : 21223
# Arena of Valor: 5v5 Arena Game : 438911
# Mobile Legends: Bang Bang : 8219586
# Kill Shot Bravo: Sniper FPS : 579519
# Carnivores: Dinosaur Hunter : 62636
# Hopeless Land: Fight for Survival : 250197
# Heroes Arena : 336386
# Undead Assault : 4704
# Guess the Class 🔥 AQW : 57
# Iron Blade : 161637
# Evil Apples: A Dirty Card Game : 137696
# Ghost Snap AR Horror Survival : 898
# The Walking Dead: Our World : 22435
# Ingress : 391325
# Flat Pack : 862
# Crayola Color Blaster : 17
# Guns of Boom - Online Shooter : 1226514
# Guns Royale - Multiplayer Blocky Battle Royale : 19070
# Stack It AR : 1363
# Arcraft - AR Sandbox : 469
# AR Tank Battle : 153
# Sonic the Hedgehog™ Classic : 125652
# Pacific Navy Fighter C.E. (AS) : 11379
# My OldBoy! Free - GBC Emulator : 51787
# My Boy! Free - GBA Emulator : 531074
# SAMURAI vs ZOMBIES DEFENSE : 407788
# Five Nights at Freddy's 4 Demo : 889425
# Five Nights at Freddy's 3 Demo : 1041836
# Nights at Cube Pizzeria 3D – 2 : 47151
# Rivals at War: Firefight : 344819
# 7 Nights at Pixel Pizzeria - 2 : 23168
# Nights at Slender Pizzeria 3D : 2628
# One Night at Golden Freddy's : 2717
# Nights at Cube Pizzeria 3D – 4 : 7728
# Five Nights at Neighbor House : 2180
# Asylum Night Shift - Five Nights Survival : 59223
# Two Nights at jumpscare : 596
# Five Nights at Pizzeria : 1976
# Block Battles: Heroes at War - Multiplayer PVP : 6698
# Five Nights at Flappy's : 4041
# 5 Nights at Cube Pizzeria City : 2691
# Au Mobile: Audition Chính Hiệu : 85278
# AU Mobile Indonesia : 16521
# Super Dancer : 91667
# Au-allstar for KR : 2433
# Super Dancer VN : 24312
# Love Dance : 29462
# Avatar Musik : 159063
# Armored Warfare: Assault : 7718
# Auction Wars : Storage King : 29062
# iSniper 3D Arctic Warfare : 35572
# Modern Action Commando 3D : 492
# Call of Duty®: Heroes : 1604146
# AXE.IO - Brutal Survival Battleground : 3845
# Axe Champ : 141
# Axe Champ Hit : 1
# Axe Champion : 21
# Vikings Stickman Axe Fighting : 924
# Axetatic - Axe Throwing Game : 29
# Axe Champs! Wars : 8
# Axe Knight : 52
# The Vikings : 15806
# Knife&Axe Throwing : 440
# Stickman and Axe : 69
# Axe Throw: Flip Champ Axes Champion Throwing Games : 1
# Axe Man : 53
# Dead Zombie Evil Killer:Axe : 71
# Zlax.io Zombs Luv Ax : 6344
# Clash of Axe: Flippy Lumberjack Action X : 6
# Flippy Axe : Flip The Knife & Axe Simulator : 7
# Cyborg AX-001 : 0
# Woodman Deluxe : 82
# ¡Ay Metro! : 489
# Ay Vamos - PJ. Balvin - Piano : 0
# San Andreas Crime Stories : 162530
# Miami crime simulator : 254518
# Strange Hero: Future Battle : 88901
# Mad Day - Truck Distance Game : 29270
# AZ Rockets : 162
# Ba Cristi : 196
# Banana Kong : 3452530
# Space Shooter : Galaxy Attack : 169661
# BC Slots - The Lost Reels FREE : 209
# Millionaire : Who want to be? : 4396
# Beauty Idol: Fashion Queen : 128367
# Hard Time (Prison Sim) : 275843
# Battlefield™ Companion : 263907
# BF at Sea Refueled : 1849
# Bullet Force : 634159
# BF Combat: Genesis : 3322
# Combat BF: Black Ops 3 : 7699
# BF Frontline City : 29798
# Faketalk - Chatbot : 63056
# Block Gun 3D: Call of Destiny : 31883
# BLOOD & GLORY: IMMORTALS : 101762
# Block Gun 3D: Ghost Ops : 142693
# Rento - Dice Board Game Online : 205830
# Survival Run with Bear Grylls : 128579
# VIP Backgammon Free : Play Backgammon Online : 389
# Out of Bounds BH Demo : 3
# Bi-Tank : 12
# Bike Rivals : 212067
# Bingo Party - Free Bingo Games : 155694
# BJ's Bingo & Gaming Casino : 501
# BJ Bridge Free (2018) : 20
# BJ Bridge Acol Beginner 2018 : 11
# BJ Bridge Standard American 2018 : 1
# BJ Strategy Tester : 1
# Cards Casino:Video Poker & BJ : 325
# Real Casino:Slot,Keno,BJ,Poker : 341
# Basic Strategy Training BJ 21 : 0
# BJ card game blackjack : 3
# BLACKJACK! : 524467
# Blackjack : 52199
# BlackJack -21 Casino Card Game : 2066
# BlackJack 21 Pro : 26744
# Ultimate BlackJack 3D FREE : 1686
# Blood Domination - BL Game : 415
# Heirs & Graces : 125
# Lust in Terror Manor - The Truth Unveiled | Otome : 355
# BL!TZ - Endless : 21
# BL-ED: From BLUE to RED : 3
# Teen Patti by BL Games : 496
# Word Hunt : 59
# Skip-Bo™ Free : 46801
# Red Ball 4 : 1432447
# Skater Boy : 1167143
# Sic Bo Online! Free Casino : 488
# Hambo : 125578
# Sic Bo Rave : 164
# Thai Sic Bo : 14283
# Bounce Classic : 38297
# Bomber Friends : 776730
# Sic Bo (Tai Xiu) - Multiplayer Casino : 152
# Carros Rebaixados BR : 20691
# Texas HoldEm Poker Deluxe (BR) : 1418
# Brick Breaker BR : 7
# Black Commando | Special Ops | FPS Shooting : 1167
# True Skateboarding Ride Skateboard Game Freestyle : 8175
# Bullshit! (Free) : 45
# Bullshite! : 48
# Block Strike : 947515
# BombSquad Remote : 13304
# BS Tractor : 3
# BS Chopper : 0
# B@dL!bs Lite : 10
# kick the buddy : 294
# Bu Hangi Ünlü? : 1
# Bu Nedir ? : 0
# BU HANGİ ŞARKI ? - 2018 : 4
# Bu Hangi Oyun ? : 2
# Bu Hangi Youtuber ? : 31
# Nedir Bu ? : 0
# Bu Hangi Dizi ? : 14
# Smashy Road: Arena : 45558
# BW-Go Free : 547
# BW-Joseki : 705
# BW-DGS plugin : 70
# BW-GnuGo : 64
# BW Switch : 1
# C3-C4-PİCASSO-ELYSEE RACİNG : 12
# Driving Cars Simulator Citroen : 3
# RC Monster Truck - Offroad Driving Simulator : 38448
# Super Jabber Jump : 85882
# Commando Adventure Assassin : 51067
# Roulette Advisor LITE : 41
# Mini Motor Racing WRT : 107497
# BMX Boy Bike Stunt Rider Game : 299
# World of Warriors: Duel : 25952
# Driving Zone : 51791
# Car Race by Fun Games For Free : 54221
# Slot Machines by IGG : 267229
# Bingo by IGG: Top Bingo+Slots! : 183343
# Voxel - 3D Color by Number & Pixel Coloring Book : 62561
# BZ Zombie VR : 12
# BZ Fingers : 15
# Sniper Gun Shot 3D: Impossible Missions : 20
# Elite Commando Shooting War : 14
# Animal Hunting: Sniper Shooting : 0
# Creative Destruction : 201426
# Sonic CD Classic : 26138
# ARK: Survival Evolved : 51523
# Grim Tales: The Wishes CE : 4923
# CrossFire: Legends : 144040
# Special Forces Group 2 : 1432809
# Motocross Motorbike Simulator Offroad : 51366
# Sermon on Proverbs CH Spurgeon : 35
# Chicken Invaders 3 : 52390
# Trovami se ci riesci : 11
# CJ: Strike Back : 29330
# The Grand Wars: San Andreas : 29990
# The Grand Way : 1995
# San Andreas City : Auto Theft Car gangster : 923
# Miami Crime Vice Town : 154519
# CJ Poker Odds Calculator : 207
# Gangster City Auto Theft : 350
# China Town Auto Theft 2 : 364
# Grand Gangsters 3D : 401643
# Gang Wars of San Andreas : 9898
# Sin City Hero : Crime Simulator of Vegas : 3371
# Zombie Death Shooter : 17372
# Project Grand Auto Town Sandbox Beta : 7885
# CONTRACT KILLER: ZOMBIES (NR) : 206602
# CKZ ORIGINS : 219821
# 211:CK Lite : 3
# CONTRACT KILLER: ZOMBIES : 144545
# Can Knockdown 3 : 349503
# Sky Streaker - Gumball : 37513
# Just A Regular Arcade : 40847
# Dreamland Arcade - Steven Universe : 6386
# Adventure Time Run : 24628
# Glitch Fixers: Powerpuff Girls : 39698
# StirFry Stunts - We Bare Bears : 121533
# Angelo Rules - Crazy day : 108336
# Multicraft Miner Exploration : 14563
# Alex & Co Quiz : 9
# Them Bombs: co-op board game play with 2-4 friends : 8038
# Chinese Chess ( Xiangqi Free ) : 963
# Chinese Chess / Co Tuong : 6947
# Call of Mini™ Zombies 2 : 248417
# 2-Player Co-op Zombie Shoot : 33
# IV Go（get IV for Pokemon） : 132282
# CP Trivia : 5
# CQ: Lost In Transmission : 4
# Palavras la cq : 783
# Gunship Modern Combat 3D : 3247
# Sniper Killer Shooter : 119368
# Snowboard Racing Free Fun Game : 4552
# Toughest Game Ever 2 : 293086
# RIDE ZERO : 8778
# Critical Strike CS: Counter Terrorist Online FPS : 22773
# Assault Line CS Online Fps Go : 52163
# Standoff 2 : 299046
# Counter Online FPS Game : 41089
# Combat Strike CS 🔫 Counter Terrorist Attack FPS💣 : 1019
# Ultimate Quiz for CS:GO - Skins | Cases | Players : 2526
# Аim Training for CS : 2328
# Sniper Traning for CS GO : 655
# Your rank CS:GO : 4946
# Mobile CS:GO : 1015
# Counter Terrorist Gun Strike CS: Special Forces : 211
# Shooter Sniper CS - FPS Games : 14823
# CS16Client : 8668
# Counter Attack - Multiplayer FPS : 112565
# What's Your CS:GO rank? : 278
# Map Callouts for CS:GO : 211
# Quiz CS:GO players : 460
# Puzzle for CS:GO : 247
# CT-ART 4.0 (Chess Tactics 1200-2400 ELO) : 8191
# Moto Rider : 115176
# Crazy Wheels : 121082
# Cartoon Wars: Blade : 165656
# Racing CX : 4
# Freecell CY : 387
# Cytus : 541732
# Shadowverse CCG : 47340
# SuperBikers 2 : 6200
# Dan the Man: Action Platformer : 528550
# Geometry Dash SubZero : 260527
# Quiz TRUE or FALSE : 2464
# The Visitor : 39895
# Just Dance Now : 794058
# DB Ultra Saiyan Battle : 33
# Injustice 2 : 504765
# Injustice: Gods Among Us : 2440877
# Ultimate DC Challenge : 937
# Justice League Action Run : 22333
# Quiz DC : 33
# MARVEL Avengers Academy : 304106
# DC Universe Quiz : 11
# Power Rangers: Legacy Wars : 264755
# WDAMAGE: Car Crash Engine : 47386
# Word Search multilingual : 32849
# Piano Free - Keyboard with Magic Tiles Music Games : 785622
# Bike Racing 3D : 951435
# Truck Driver Cargo : 257531
# Checkers : 375996
# Scratch Logo Quiz. Challenging brain puzzle : 152102
# DF Squid : 1
# DG Mobile : 59
# Destroy Gunners Σ : 10786
# DH Texas Poker - Texas Hold'em : 562345
# DEER HUNTER CLASSIC : 3941129
# DEER HUNTER RELOADED : 314774
# DH Pineapple Poker OFC : 1878
# Call of Mini™ Dino Hunter : 326042
# Bike Mayhem Free : 331692
# Car Crash III Beam DH Real Damage Simulator 2018 : 151
# DEER HUNTER CHALLENGE : 38767
# Defender : 152395
# Texas HoldEm Poker Deluxe : 396090
# Deck Heroes: Legacy : 466495
# Shred! Downhill Mountainbiking : 41683
# Archery Physics Objects Destruction Apple shooter : 6026
# Fancy Pants Adventures : 55952
# Lep's World 3 🍀🍀🍀 : 771001
# Robbery Bob : 617732
# Nyan Cat: Lost In Space : 371318
# DK Quiz : 1628
# Super DK vs Kong Brother Advanced Free Classic : 66
# DM EVOLUTION : 450
# DM Adventure : 0
# Destiny Ninja Shall we date otome games love story : 13079
# Free Poker Games : Downtown Casino - Texas Holdem : 2032
# NARUTO X BORUTO NINJA VOLTAGE : 267395
# Does not Commute : 154108
# Kung Fu Do Fighting : 271214
# How well do you know me? : 1290
# Endless Ducker : 8193
# that's lit : 1115
# Dash Quest Heroes : 8432
# Jungle book-The Great Escape : 2362
# Bunny Skater : 139432
# The Walking Zombie: Dead City : 58575
# Dr. Parking 4 : 475369
# Dr. Driving 2 : 358633
# Dr. Parker : Parking Simulator : 14253
# Dr. Parker : Real car parking simulation : 15829
# Dr. Rocket : 42182
# Dr. Dominoes : 2700
# Dr. Gomoku : 85317
# Dr. Chess : 97209
# Dr Dre - Beatmaker : 146
# Dr Driving Racer : 183
# Dr. Shogi : 19291
# NDS Emulator - For Android 6 : 14002
# Free DS Emulator : 22896
# nds4droid : 107778
# MegaNDS (NDS Emulator) : 2218
# EmuBox - Fast Retro Emulator : 1576
# Simple x3DS Emulator - BETA : 0
# DS Tower Defence : 768
# RetroArch : 21423
# Wheelie Challenge : 137338
# Sword of Chaos - Lame du Chaos : 23599
# Hotel Insanity : 3816
# Shoot! DX - lights for FREE : 4
# American Sniper City Fight Shooting Assassin : 395
# Street Skater 3D : 120852
# DZ-JOKER : 6
# Super ball DZ : 24
# Ludo Dz : 17
# Need for Speed™ No Limits : 3344300
# Peggle Blast : 166251
# Heroes of Dragon Age : 70389
# SCRABBLE : 172281
# Asphalt Xtreme: Rally Racing : 567984
# Modern Combat 5: eSports FPS : 2903386
# Mass Effect: Andromeda APEX HQ : 4490
# Mirror’s Edge™ Companion : 1995
# Gear.Club - True Racing : 140658
# Mental Hospital:EB 2 Lite : 5341
# EC Mover : 5
# EF Jumper : 4
# E.G. Chess Free : 505
# L.A. Crime Stories 2 Mad City Crime : 3946
# LA Stories 4 New Order Sandbox 2018 : 17453
# L.A. Crime Stories Mad City Crime : 30008
# Betul Ke Bohong Eh? : 601
# Eh Amego! : 13388
# MazeMilitia Classic Multiplayer Shooting Game : 1294
# ZOMBIE RIPPER : 16073
# Horror Hospital : 63986
# Mad Skills Motocross : 32522
# Pineapple Pen : 157264
# Guess The Emoji : 76627
# Camping RV Caravan Parking 3D : 5290
# Grand Bat Superhero Flying Assault Rescue Mission : 1094
# Zombie Frontier : 326689
# RUN JUMP RUN-fun games for free : 661
# Tamago egg : 49
# Let's Poke The Egg : 9051
# Survival: Prison Escape : 127810
# TAMAGO Monsters Returns : 104583
# Traffic Sniper Counter Attack : 5339
# Rope Superhero Unlimited : 6735
# Extreme Super Car Driving 3D : 23104
# Fast Racing Car Simulator : 8482
# Beach Head Shooting Assault : 555
# Stickman Warriors Heroes 2 : 13714
# Dead Target Zombie Shooting US Sniper Killer Squad : 240
# Dubai Racing : 16237
# Robot Fighting Games™ - Real Boxing Champions 3D : 30
# Ghost Hunting camera : 3048
# Santa Panda Bubble Christmas : 101
# Racing Moto : 697805
# Train Racing Games 3D 2 Player : 192374
# Adivina el cantante de Trap y Reggaeton : 1914
# Fernanfloo : 526595
# Adivina el Emoji : 2536
# Red Hands – 2-Player Games : 93608
# Get 'Em : 7904
# Live Hold’em Pro Poker - Free Casino Games : 1123190
# Beach Shoot Em Up: Head Hunter : 1218
# Stick 'Em Up 2 Starter Edition : 2102
# Shoot`Em Down: Shooting game : 7972
# Texas Hold’em Poker + | Social : 4416
# PlayTexas Hold'em Poker Free : 3543
# HAWK – Force of an Arcade Shooter. Shoot 'em up : 190274
# Texas Hold'em Poker : 12846
# Poker Live! 3D Texas Hold'em : 6143
# Fun Texas Hold'em Poker : 32831
# Dragonplay™ Poker Texas Holdem : 197979
# Punch em : 2208
# Zynga Poker – Texas Holdem : 1986068
# Boyaa Poker (En) – Social Texas Hold’em : 71468
# World Series of Poker – WSOP Free Texas Holdem : 910051
# Texas Holdem Poker Pro : 114479
# Rage Fight of Streets - Beat Em Up Game : 1489
# HANGAME Casino - Baccarat & Texas Hold'em : 8608
# PokerStars Play: Free Texas Holdem Poker Game : 14989
# Texas Holdem Poker : 127831
# Big Fish Casino – Play Slots & Vegas Games : 382100
# TRANSFORMERS: Forged to Fight : 291941
# Texas Holdem & Omaha Poker: Pokerist : 187200
# Governor of Poker 2 - OFFLINE POKER GAME : 246538
# Squadron - Bullet Hell Shooter : 177542
# Words With Friends – Play Free : 711719
# Classic Words Solo : 135739
# Sports Car Driving Simulator 2018 : 2178
# The Great Wobo Escape Ep. 1 : 5449
# The Visitor: Ep.2 - Sleepover Slaughter : 5731
# The Visitor: Ep.1 - Kitty Cat Carnage : 3017
# Dr.Slender Ep 1 Guide (Eng) : 454
# Decay: The Mare - Ep.1 (Trial) : 5291
# EP Gem Hunter : 79
# Gate Of Death Ep: 1 : 7
# Oggy : 49971
# Invasion: Defend EU : 7
# R-EU-READY : 13
# Speed Racing Ultimate 2 : 66894
# Countries of the European Union (Quiz) : 11
# I Know Stuff : 214923
# Water Surfer Racing In Moto : 2233
# Ew, the small alien : 5
# Rescue Robots Survival Games : 27557
# Bike Race - Bike Blast Rush : 83891
# ETERNITY WARRIORS 2 : 568391
# Snes9x EX+ : 70351
# Virtual Dice EX : 40
# Eyes - The Scary Horror Game Adventure : 499483
# Sudoku Master : 58387
# Jungle Monkey Run : 54082
# Ez Mirror Match : 3344
# CNY Slots : Gong Xi Fa Cai 发财机 : 33
# Golden HoYeah Slots - Real Casino Slots : 201537
# FaFaFa™ Gold Casino: Free slot machines : 11051
# Heart of Vegas™ Slots – Free Slot Casino Games : 264282
# FG SPINNER : 2
# BROTHER IN WARS: GUNNER CITY WARLORDS : 8649
# Angry Birds Space HD : 43645
# Police Car Driver : 83671
# Modern Sniper Strike: Best Commando Action 2k18 : 164
# Moto Fighter 3D : 85410
# BMX Boy : 839206
# Crazy Bike attack Racing New: motorcycle racing : 20364
# Fields of Battle : 71476
# Family Guy The Quest for Stuff : 995002
# Toy Attack : 3878
# SnowMobile Parking Adventure : 12257
# Zombie Sniper 3D III : 8122
# Shoot Hunter-Gun Killer : 320334
# Fast Motorcycle Driver 2016 : 28151
# Forgotten Hill: Fall : 1063
# Forgotten Hill Mementoes : 2027
# Forgotten Hill: Surgery : 2431
# Forgotten Hill: Puppeteer : 2917
# FJ Final Join , Circles Game : 32
# Offroad drive : 4x4 driving game : 2071
# Rope Hero: Vice Town : 452589
# Drive 4x4 Luxury SUV Jeep : 2183
# Motocross Mayhem : 35171
# Dino Defends king 3 – Dinosaur T rex Hunter Games : 182
# Block Gun 3D: Haunted Hollow : 16282
# Navy Gunner Shoot War 3D : 103199
# Drift Legends : 33788
# FK (FlightKid) : 2
# Toy Truck Rally 3D : 301895
# PRO MX MOTOCROSS 2 : 25275
# FRONTLINE COMMANDO : 1351833
# Gun Builder ELITE : 88941
# Magnum 3.0 Gun Custom SImulator : 16815
# Gun Club Armory : 55014
# Armed Cam Gun Pack : 1012
# Fo Fo Fish : 5
# 4x4 Jeep Racer : 7279
# Frontline Terrorist Battle Shoot: Free FPS Shooter : 9183
# Mad Dash Fo' Cash : 14
# Race Manager FP : 196
# FP Runner : 38
# Modern Counter Terrorist FPS Shoot : 795
# Monster Ride Pro : 1
# BEBONCOOL GAMEPAD V1.0 : 404
# Modern Strike Online : 834117
# Modern Counter Terror Attack – Shooting Game : 340
# Big Hunter : 245455
# Modern Counter Global Strike 3D : 297
# Modern Counter Global Strike 3D V2 : 368
# Winter Wonderland : 1287
# Soccer Clubs Logo Quiz : 21661
# Sid Story : 28510
# Fatal Raid - No.1 Mobile FPS : 56496
# Poker Pro.Fr : 5442
